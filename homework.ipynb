# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OrdinalEncoder, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

from sklearn.feature_selection import VarianceThreshold, SelectFromModel, RFECV, SequentialFeatureSelector

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import KFold, cross_val_score, train_test_split, cross_validate
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.metrics import accuracy_score

from sklearn.datasets import make_classification, load_wine, load_breast_cancer, load_diabetes, load_digits

# %%
plt.style.use('seaborn-darkgrid')

# %%
def plot_scatter(x, y, auto_scaled=True, title=None, clusters=None):
    plt.figure(figsize=(6, 6))
    plt.scatter(x, y, c=clusters, cmap='brg')
    
    if not auto_scaled:
        plt.axis('square')
    
    plt.grid(True)
    plt.title(title)
    
    plt.show()
    
def return_X_y(data, target_column):
    return data.drop(target_column, axis=1), data[target_column]

# %%
wine_sklearn = load_wine(as_frame=True)
wine_data, wine_labels = wine_sklearn['data'], wine_sklearn['target']

# %% [markdown]
# # Homework

# %% [markdown]
# ## Exercise  1 - Scaling (2 points)

# %% [markdown]
# Perform standardization for wine dataset (`wine_data`) using only basic python, numpy and pandas (without using `StandardScaler` and sklearn at all). Implementation of function (or class) that can get dataset as input and return standardized dataset as output is preferrable, but not necessary.
#
# Compare you results (output) with `StandardScaler`.
#
# **NOTE:**
#
# - 1 point for functional version, 2 points for implementing scaling as sklearn pipeline compartible class.
# - Maximum for the exercise is 2 points.

# %% [markdown]
# ### Simple version (1 point)

# %%
# 1 point
def scale(X):
    data = X.copy()
    std = data.std(axis=0,ddof=0)
    mean = data.mean(axis=0)
    data = (data - mean) / std
    return data

# %%
assert np.allclose(np.array(scale(wine_data)), StandardScaler().fit_transform(wine_data))

# %% [markdown]
# ### Pipeline Version (2 points)

# %%
# 2 points
from sklearn.base import BaseEstimator, TransformerMixin
class CustomScaler(BaseEstimator, TransformerMixin):
    def __init__(self, copy=True, with_mean=True, with_std=True):
        self.copy = copy
        self.with_mean = with_mean
        self.with_std = with_std
        self.mean = None
        self.std = None

    def fit(self, X, y=None):
        
        if self.with_mean:
            self.mean = X.mean(axis=0)
        else:
            self.mean = np.zeros(X.shape[1])
            
        if self.with_std:
            self.std = X.std(axis=0,ddof=0)
        else:
            self.std = np.ones(X.shape[1])
            
        return self

    def transform(self, X, y=None, copy=None):
        if copy:
            data = X.copy()
            return (data - self.mean) / self.std
        else:
            return (X - self.mean) / self.std

# %%
assert np.allclose(CustomScaler().fit_transform(wine_data), StandardScaler().fit_transform(wine_data))

# %% [markdown]
# ## Exercise  2 - Visualization (3 points)

# %% [markdown]
# As noted earlier, standardization/normalization of data can be crucial for some distance-based ML methods.
#
# Let’s generate some toy example of unnormalized data and visualize the importance of this process once more:

# %%
feature_0 = np.random.randn(1000) * 10   
feature_1 = np.concatenate([np.random.randn(500), np.random.randn(500) + 5])
data = np.column_stack([feature_0, feature_1])
data
# Out:
# array([[  3.94718115,  -0.6423954 ],
#        [-14.74914604,   0.50388036],
#        [  5.54583388,   0.68454062],
#        ...,
#        [ 16.48023894,   4.9886194 ],
#        [-20.57340231,   6.2197721 ],
#        [  4.38697248,   2.18920954]])

# %%
plot_scatter(data[:, 0], data[:, 1], auto_scaled=True, title='Data (different axes units!)')

# %% [markdown]
# **NOTE:** on the plot above axes are scaled differently and we can clearly see two potential *classes/clusters*. In fact `matplotlib` performed `autoscaling` (which is basically can be considered as `MinMaxScaling` of original data) just for better visualization purposes.
#
# Let's turn this feature off and visualize the original data on the plot with equally scaled axes:

# %%
plot_scatter(data[:, 0], data[:, 1], auto_scaled=False , title='Data (equal axes units!)')

# %% [markdown]
# This picture is clearly less interpretable, but much closer to "how distance-based algorithm see the original data": separability of data is hardly noticable only because the variation (std) of x-feature is much bigger in absolute numbers.

# %% [markdown]
# Perform `StandardScaling` and `MinMaxScaling` of original data; visualize results for each case (**use `plot_scatter` with `auto_scaled=False`**):

# %% [markdown]
# ### MinMaxScaling (0.5 point)

# %%
minmax_scaler = MinMaxScaler()
data_scaled_minmax = minmax_scaler.fit_transform(data)
data_scaled_minmax
# Out:
# array([[0.59965491, 0.27959719],
#        [0.31130598, 0.37831853],
#        [0.62431054, 0.39387764],
#        ...,
#        [0.79294922, 0.7645602 ],
#        [0.22147989, 0.87059145],
#        [0.6064377 , 0.52346507]])

# %% [markdown]
# ### StandardScaler (0.5 point)

# %%
std_scaler = StandardScaler()
data_scaled_std = std_scaler.fit_transform(data)
data_scaled_std
# Out:
# array([[ 0.35619645, -1.17632313],
#        [-1.49868339, -0.74777227],
#        [ 0.51480026, -0.68022996],
#        ...,
#        [ 1.59961265,  0.92890874],
#        [-2.07651322,  1.38919201],
#        [ 0.39982855, -0.11768891]])

# %% [markdown]
# ### (Bonus) K-means (2 points)

# %% [markdown]
# Illustrate the impact of scaling on basic distance-based clustering algorithm [K-means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) using `data` generated above.
#
# **NOTE:** basically, you don't need understanding K-means algorithm here, you just need to:
#
# 1) run algorithm (with k=2, k - number of clusters/classes) on unscaled data
# 2) run algorithm (with k=2) on scaled data
# 3) plot results: highlight different clusters using different colors.
#
# You can use this [question](https://stats.stackexchange.com/questions/89809/is-it-important-to-scale-data-before-clustering/89813) as a hint, but I recommend you to plot results using `plot_scatter` with `equal_scaled=True`: it might help you to intuitively understand the reasons of such scaling impact.

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(data)
clusters_unscaled = kmeans.predict(data)

kmeans.fit(data_scaled_std)
clusters_scaled_std = kmeans.predict(data_scaled_std)

kmeans.fit(data_scaled_minmax)
clusters_scaled_minmax = kmeans.predict(data_scaled_minmax)

# %%
plot_scatter(data[:,0], data[:,1], auto_scaled=False, title='Clusters on unscaled data', clusters=clusters_unscaled)

# %%
plot_scatter(data_scaled_std[:,0], data_scaled_std[:,1], auto_scaled=False, title='Clusters on standard scaled data', clusters=clusters_scaled_std)

# %%
plot_scatter(data_scaled_minmax[:,0], data_scaled_minmax[:,1], auto_scaled=False, title='Clusters on minmax scaled data', clusters=clusters_scaled_minmax)

# %% [markdown]
# We can see that MinMax scaling gave us the best visualisation, standard scaled data also gives an okay plot, both of them are definetely better than the plot on scaled data, anyway.

# %% [markdown]
# ## Exercise  3 - Preprocessing Pipeline (2 points)

# %%
wine_train, wine_val, wine_labels_train, wine_labels_val = train_test_split(wine_data, wine_labels, 
                                                                            test_size=0.3, random_state=42)

# %% [markdown]
# Train model (for example, `LogisticRegression(solver='liblinear', penalty='l1')` on raw `wine_train` data; then train same model after data scaling; then add feature selection (and train model again on scaled data). For each experiment all required preprocessing steps (if any) should be wrapped into sklearn pipeline.
#
# Measure `accuracy` of all 3 approaches on `wine_val` dataset. Describe and explain results.

# %%
lr_unscaled = Pipeline([
    ('LogRegression', LogisticRegression(solver='liblinear', penalty='l1'))       
    ]) 

lr_scaled = Pipeline([
    ('Scaler', StandardScaler()),
    ('LogRegression', LogisticRegression(solver='liblinear', penalty='l1'))       
    ])         

lr_select_from = Pipeline([
    ('Scaler', StandardScaler()),
    ('Selector', SelectFromModel(LogisticRegression(solver='liblinear', penalty='l1'))),
    ('LogRegression', LogisticRegression(solver='liblinear', penalty='l1'))       
    ]) 

lr_sequential = Pipeline([
    ('Scaler', StandardScaler()),
    ('Selector', SequentialFeatureSelector(LogisticRegression(solver='liblinear', penalty='l1'), n_features_to_select=8)),
    ('LogRegression', LogisticRegression(solver='liblinear', penalty='l1'))       
    ])

# %%
def fit_evaluate(pipeline,X_train,y_train, X_val, y_val, title):
    pipeline.fit(X_train,y_train)
    print(title)
    print('Train score = ',pipeline.score(X_train,y_train))
    print('Test score = ',pipeline.score(X_val,y_val))
    model = pipeline['LogRegression']
    weights = (model.coef_).mean(axis=0)
    print(f'Amount of 0 weights: {np.isclose(np.abs(weights),0).sum()}')
    if np.isclose(np.abs(weights),0).sum() > 0:
        useless_features = np.array(X_train.columns)[np.where(np.isclose(np.abs(weights),0))]
        print(f'Features with zero weights: {useless_features}')
        
def fit_select_evaluate(pipeline,X_train,y_train, X_val, y_val, title):
    pipeline.fit(X_train,y_train)
    print(title)
    print('Train score = ',pipeline.score(X_train,y_train))
    print('Test score = ',pipeline.score(X_val,y_val))
    selector = pipeline['Selector']
    print(f'Selected features: {X_train.columns[selector.get_support()].values}')
    print(f'Not selected features: {list(set(X_train.columns) - set(X_train.columns[selector.get_support()].values))}')

# %%
fit_evaluate(lr_unscaled, wine_train, wine_labels_train, wine_val, wine_labels_val,title='Logistic regression on raw data')
# Out:
# Logistic regression on raw data
# Train score =  0.967741935483871
# Test score =  0.9814814814814815
# Amount of 0 weights: 3
# Features with zero weights: ['total_phenols' 'nonflavanoid_phenols' 'hue']

# %%
fit_evaluate(lr_scaled,  wine_train, wine_labels_train, wine_val, wine_labels_val, title='Logistic regression on scaled data')
# Out:
# Logistic regression on scaled data
# Train score =  1.0
# Test score =  0.9814814814814815
# Amount of 0 weights: 3
# Features with zero weights: ['magnesium' 'total_phenols' 'nonflavanoid_phenols']

# %% [markdown]
# We can see that test score didn't change, but we achieved maximum test score of 1 when we scaled the data.
#
# With the help of L1 penalty we figured out features that are not that important for our predictions.

# %%
features = list(set(wine_data.columns) - set(['total_phenols','nonflavanoid_phenols', 'hue', 'magnesium']))

fit_evaluate(lr_unscaled, wine_train[features], wine_labels_train, wine_val[features], wine_labels_val, title='Logistic regression on raw selected data')
# Out:
# Logistic regression on raw selected data
# Train score =  0.967741935483871
# Test score =  0.9629629629629629
# Amount of 0 weights: 1
# Features with zero weights: ['ash']

# %%
fit_evaluate(lr_scaled, wine_train[features], wine_labels_train, wine_val[features], wine_labels_val, title='Logistic regression on selected scaled data')
# Out:
# Logistic regression on selected scaled data
# Train score =  1.0
# Test score =  1.0
# Amount of 0 weights: 0

# %% [markdown]
# After simple feature selection I tried fitting model on scaled and unscaled data.
#
# Unscaled data resulted in worse accuracy then without any feature selection whatsoever.
#
# However, scaled data after feature selection got us perfect train and test scores!
#
# I tried other feature selection methods below:

# %%
fit_select_evaluate(lr_select_from, wine_train, wine_labels_train, wine_val, wine_labels_val, title='Logistic regression with SelectFromModel')
# Out:
# Logistic regression with SelectFromModel
# Train score =  1.0
# Test score =  0.9814814814814815
# Selected features: ['alcohol' 'malic_acid' 'ash' 'alcalinity_of_ash' 'flavanoids'
#  'proanthocyanins' 'color_intensity' 'hue' 'od280/od315_of_diluted_wines'
#  'proline']
# Not selected features: ['total_phenols', 'nonflavanoid_phenols', 'magnesium']

# %%
fit_select_evaluate(lr_sequential, wine_train, wine_labels_train, wine_val, wine_labels_val, title='Logistic regression with SequentialFeatureSelector (n=9)')
# Out:
# Logistic regression with SequentialFeatureSelector (n=9)
# Train score =  1.0
# Test score =  0.9629629629629629
# Selected features: ['alcohol' 'ash' 'alcalinity_of_ash' 'magnesium' 'flavanoids'
#  'proanthocyanins' 'hue' 'proline']
# Not selected features: ['malic_acid', 'od280/od315_of_diluted_wines', 'total_phenols', 'color_intensity', 'nonflavanoid_phenols']

# %% [markdown]
# Generally, sklearn feature selection methods gave good results that are similar to my conclusions which features were good and which were not so. In comparison, SelectFromModel did a little better.

# %% [markdown]
# ## Exercise 4 - manual PCA (5 points)
# The task is to solve PCA as an optimization problem, without explicitly doing eigen value decomposition.
# In the most general setting PCA is minimization of reconstruction error of a projection of given rank $q$
#
# $$\min_{\mu, \lambda_1,\ldots, \lambda_n, \mathbf{V}_q} \sum_{i=1}^n ||x_i - \mu - \mathbf{V}_q \lambda_i||^2$$
#
# With a number of steps that can be found here https://stats.stackexchange.com/a/10260 this task transforms to
#  $$\max_{u_i} \sum_{i=1}^q u_i^T \mathbf{S} u_i$$
#  where $\mathbf{S}$ is the sample covariance matrix (after standartization) and $u_1, \ldots, u_q$ are the $q$ are orthonormal columns in $\mathbf{V}_q$.
#  Let us solve this optimization problem with `scipy.optimize` library.
#
#  Additional 2 point are given for visualization of the results.

# %% [markdown]
# ### PCA (3 points)

# %%
wine_data, wine_labels = wine_sklearn['data'], wine_sklearn['target']

# %% [markdown]
# Find a covariance matrix of standartized data and assing it to S.

# %%
wine_data_scaled = StandardScaler().fit_transform(wine_data)

def custom_cov(X):    
    return (X.T @ X) / (X.shape[0] - 1)

S = custom_cov(wine_data_scaled)

# %% [markdown]
# If your code is correct, the following assert should be Ok.

# %%
assert np.allclose(S, np.cov(wine_data_scaled.T))

# %%
assert np.allclose(np.linalg.norm(S), 5.787241159764734)

# %%
from scipy.optimize import minimize

def objective(x):
    
    return -(x @ S @ x)

def norm_constraint(x):
    return 1 - np.linalg.norm(x)

con1 = {'type': 'eq', 'fun': norm_constraint}

x0 = np.zeros(13)

sol = minimize(objective, 
               x0, 
               constraints = [con1]
              )
x0 = sol.x
x0
# Out:
# array([ 0.14433534, -0.24519361, -0.00205056, -0.23931168,  0.14199141,
#         0.39466364,  0.42293322, -0.29853203,  0.31343065, -0.08861937,
#         0.29670785,  0.37617241,  0.28674886])

# %% [markdown]
# Hurray! We have first vector! Let's do another one.

# %%
def orthogonality_constraint(x):
    return np.dot(x,x0)

con2 = {'type': 'eq', 'fun': orthogonality_constraint}

x1 = np.zeros(13)


sol = minimize(objective, 
               x1, 
               constraints = [con1,con2]
              )

x1 = sol.x
x1
# Out:
# array([ 0.48365333,  0.22493154,  0.31608553, -0.01057988,  0.29962576,
#         0.06504698, -0.00335861,  0.02878181,  0.03929675,  0.52998504,
#        -0.27923657, -0.1644944 ,  0.3649069 ])

# %% [markdown]
# If your solution is correct, the following asserts should be Ok.

# %%
assert np.allclose(x0@S@x0, 4.732436977583595)
assert np.allclose(x1@S@x1, 2.5110809296451233)

# %% [markdown]
# ### Visualization (2 points)

# %% [markdown]
# Visualize the points after applying custom dimension reduction with 2 components.

# %%
feature_vectors = np.vstack((x0,x1))
wine_data_transformed = (feature_vectors @ wine_data_scaled.T).T


plot_scatter(wine_data_transformed[:,0], wine_data_transformed[:,1], auto_scaled=False, title='Wine data after applying PCA', clusters=wine_labels)

# %% [markdown]
# I'd like to compare this visualisation with something we could.ve done with 13-dimensional wine data alone.
#
# For example, we can pass to scatter plot two features that correlate with target the most.
#
# (I realize that checking correlation with target is not a good way of selecting features, I just used it as a way to get something to visualize)

# %%
tmp = wine_data.copy()
tmp['target'] = wine_labels
corr_matrix = tmp.corr()
target_corr = corr_matrix['target'].sort_values(ascending=False).drop(labels=['target'])
feature_idx = [list(wine_data.columns).index(feat) for feat in target_corr[:2].index.values]

plot_scatter(wine_data_scaled[:,feature_idx[0]], wine_data_scaled[:,feature_idx[1]], auto_scaled=False, title='Wine data without PCA', clusters=wine_labels)

# %% [markdown]
# Visualisation without PCA is way messier, it's hard to differenciate the clusters.
#
# On PCA visualisation we can tell clusters apart easily.

# %% [markdown]
# ## Exercise 5 - Boruta (3 points)
#
# Let us classify handwritten digits 0, 1 and 2.
# To make task not so easy the images are binarized (no shadows of gray present) as it happens with xerocopied documents.
#
# Let us also find out to which parts of an image there's no need to look in order to clasify three digits of interest.

# %%
X, y = load_digits(n_class=3, return_X_y=True, as_frame=True)
X = (X>10).astype(int)

# %%
f, ax = plt.subplots(1,3,figsize=(10,4))
for i in range(3):
    ax[i].imshow(X.iloc[i].values.reshape(8,8))
    ax[i].set_title(f"This is digit {y[i]}.")
plt.suptitle("First three images.")
plt.show()

# %% [markdown]
# Split data into train and test, let test size be 30% of the dataset and fix random state to 42:

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y,test_size=0.3, random_state=42)

# %%
assert y_val.shape[0] == 162
assert y_val.sum() == 169

# %% [markdown]
# Fit a RandomForestClassifier with max_depth=13 and evaluate it's performance:

# %%
clf = RandomForestClassifier(max_depth=13,random_state=42)
clf.fit(X_train,y_train)
acc = clf.score(X_val,y_val)
print(acc)
# Out:
# 0.9938271604938271

# %%
assert acc > 0.98

# %% [markdown]
# Now we will use Boruta to find redundand pixels. If the package is not installed in your system, uncomment and run the following cell.

# %%
#! pip install boruta

# %%
from boruta import BorutaPy

feat_selector = BorutaPy(RandomForestClassifier(max_depth=13), 
                         n_estimators='auto', 
                         verbose=0, 
                         max_iter=100,
                         random_state=42)

feat_selector.fit(np.array(X_train),np.array(y_train))
# Out:
# BorutaPy(estimator=RandomForestClassifier(max_depth=13, n_estimators=62,
#                                           random_state=RandomState(MT19937) at 0x2315D4B0940),
#          n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x2315D4B0940)

# %% [markdown]
# Let us print redundant pixels as a mask. Does the result looks similar to mine (or to Among us chracters)?

# %%
mask = np.array(feat_selector.support_).reshape(8,8)
plt.imshow(mask);

# %% [markdown]
# It does look similar.

# %% [markdown]
# At the end let us redo  classification but only with selected features

# %%
selected_feat = list(np.array(X_train.columns)[feat_selector.support_])

# %%
clf = RandomForestClassifier(max_depth=13,random_state=42)
clf.fit(X_train[selected_feat],y_train)
acc = clf.score(X_val[selected_feat],y_val)
print(acc)
# Out:
# 0.9938271604938271

# %%
assert acc > 0.99

# %% [markdown]
# # Materials & References

# %% [markdown]
# 1. General article about feature engineering and selection (main reference):
# https://github.com/Yorko/mlcourse.ai/blob/master/jupyter_english/topic06_features_regression/topic6_feature_engineering_feature_selection.ipynb
#
# 2. Feature engineering/preprocessing, using scikit-learn API (great code examples, but really brief explanation):
# https://scikit-learn.org/stable/modules/preprocessing
#
# 3. Feature scaling/normalization:
# https://towardsdatascience.com/all-about-feature-scaling-bcc0ad75cb35
#
# 4. Log Transform/power transform:
# https://medium.com/@kyawsawhtoon/log-transformation-purpose-and-interpretation-9444b4b049c9
#
# 6. Missing values preprocessing using scikit-learn API (great code examples, great explanation):
# https://scikit-learn.org/stable/modules/impute.html
#
# 7. Feature selection scikit-learn API (great code examples, great explanation):
# https://scikit-learn.org/stable/modules/feature_selection.html
#
# 8. Melbourne housing dataset source:
# https://www.kaggle.com/anthonypino/melbourne-housing-market
